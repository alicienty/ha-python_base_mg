# %% [markdown]
# Тест 1

# %%
# Импорт класса
from data_loader import DataLoader

# 1. Создание экземпляра
loader = DataLoader("/content/health_metrics.csv")

# %%
try:
    data = loader.load_data('health_metrics.csv')
    print("Данные успешно загружены!")
except FileNotFoundError as e:
    print(f"Ошибка: {e}")
except Exception as e:
    print(f"Ошибка загрузки: {e}")
# Out:
# Данные успешно загружены!

# %%
data
# Out:
#   patient_id  age blood_pressure  cholesterol  glucose   bmi  smoker  diabetic
# 0       P001   45         120/80        185.0       92  24.1       0         0
# 1       P002   56         140/90        240.0      115  28.7       1         1
# 2       P003   34         110/75        160.0       87  22.3       0         0
# 3       P004   61         135/85          NaN      126  26.9       1         1
# 4       P005   29         118/78        175.0       94  23.5       0         0
# 5       P006   48            NaN        210.0      108  27.2       1         0
# 6       P007   52         130/85        195.0      102  25.8       0         1
# 7       P008   41         125/80        182.0       89  24.6       0         0

# %%
try:
    info = loader.get_basic_info()
    print(info)
except ValueError as e:
    print(f"Ошибка анализа: {e}")
# Out:
# Датасет имеет 8 строк/и и 8 столбца/ов. В таблице в общей сложности 2 пустых значений/я.
# Датасет имеет следующие колонки: patient_id, age, blood_pressure, cholesterol, glucose, bmi, smoker, diabetic. В свою очередь колонки имеют следующее распределение пустых значений: {'patient_id': 0, 'age': 0, 'blood_pressure': 1, 'cholesterol': 1, 'glucose': 0, 'bmi': 0, 'smoker': 0, 'diabetic': 0}

# %%
if loader.data is not None:
    print("\nПервые 5 строк данных:")
    print(loader.data.head())
# Out:
# Первые 5 строк данных:
#   patient_id  age blood_pressure  cholesterol  glucose   bmi  smoker  diabetic
# 0       P001   45         120/80        185.0       92  24.1       0         0
# 1       P002   56         140/90        240.0      115  28.7       1         1
# 2       P003   34         110/75        160.0       87  22.3       0         0
# 3       P004   61         135/85          NaN      126  26.9       1         1
# 4       P005   29         118/78        175.0       94  23.5       0         0

# %% [markdown]
# Тест 2

# %%
# 1. Создание экземпляра
loader = DataLoader("/content/sales_data.csv")

# %%
try:
    data = loader.load_data('sales_data.csv')
    print("Данные успешно загружены!")
except FileNotFoundError as e:
    print(f"Ошибка: {e}")
except Exception as e:
    print(f"Ошибка загрузки: {e}")
# Out:
# Данные успешно загружены!

# %%
data
# Out:
#          date    product     category   price  quantity region  customer_age
# 0  2024-01-01  Product_A  Electronics  299.99       5.0  North            25
# 1  2024-01-01  Product_B        Books   19.99      10.0  South            32
# 2  2024-01-02  Product_C     Clothing   49.99       NaN   East            28
# 3  2024-01-02  Product_A  Electronics  299.99       3.0   West            45
# 4  2024-01-03  Product_D         Home   89.99       7.0  North            36
# 5  2024-01-03  Product_B        Books   19.99      12.0  South            29
# 6  2024-01-04  Product_E  Electronics  199.99       2.0   East            41
# 7  2024-01-04  Product_C     Clothing   49.99       8.0   West            33

# %%
try:
    info = loader.get_basic_info()
    print(info)
except ValueError as e:
    print(f"Ошибка анализа: {e}")
# Out:
# Датасет имеет 8 строк/и и 7 столбца/ов. В таблице в общей сложности 1 пустых значений/я.
# Датасет имеет следующие колонки: date, product, category, price, quantity, region, customer_age. В свою очередь колонки имеют следующее распределение пустых значений: {'date': 0, 'product': 0, 'category': 0, 'price': 0, 'quantity': 1, 'region': 0, 'customer_age': 0}

# %%
if loader.data is not None:
    print("\nПервые 5 строк данных:")
    print(loader.data.head())
# Out:
# Первые 5 строк данных:
#          date    product     category   price  quantity region  customer_age
# 0  2024-01-01  Product_A  Electronics  299.99       5.0  North            25
# 1  2024-01-01  Product_B        Books   19.99      10.0  South            32
# 2  2024-01-02  Product_C     Clothing   49.99       NaN   East            28
# 3  2024-01-02  Product_A  Electronics  299.99       3.0   West            45
# 4  2024-01-03  Product_D         Home   89.99       7.0  North            36

# %% [markdown]
# Тест 3

# %%
# 1. Создание экземпляра
loader = DataLoader("/content/user_behavior.csv")

# %%
try:
    data = loader.load_data('user_behavior.csv')
    print("Данные успешно загружены!")
except FileNotFoundError as e:
    print(f"Ошибка: {e}")
except Exception as e:
    print(f"Ошибка загрузки: {e}")
# Out:
# Данные успешно загружены!

# %%
data
# Out:
#    user_id  session_duration  page_views  converted    country   device  \
# 0     1001             350.0           8          1        USA   mobile
# 1     1002             120.0           3          0         UK  desktop
# 2     1003             480.0          12          1     Canada   tablet
# 3     1004              65.0           2          0  Australia   mobile
# 4     1005             890.0          15          1        USA  desktop
# 5     1006               NaN           4          0         UK   mobile
# 6     1007             210.0           6          1    Germany   tablet
# 7     1008             430.0           9          1     France  desktop
# 8     1009              95.0           3          0        USA   mobile
# 9     1010             670.0          11          1     Canada  desktop
#
#   age_group
# 0     18-25
# 1     26-35
# 2     36-45
# 3     18-25
# 4     46-55
# 5     26-35
# 6     36-45
# 7     18-25
# 8       55+
# 9     26-35

# %%
try:
    info = loader.get_basic_info()
    print(info)
except ValueError as e:
    print(f"Ошибка анализа: {e}")
# Out:
# Датасет имеет 10 строк/и и 7 столбца/ов. В таблице в общей сложности 1 пустых значений/я.
# Датасет имеет следующие колонки: user_id, session_duration, page_views, converted, country, device, age_group. В свою очередь колонки имеют следующее распределение пустых значений: {'user_id': 0, 'session_duration': 1, 'page_views': 0, 'converted': 0, 'country': 0, 'device': 0, 'age_group': 0}

# %%
if loader.data is not None:
    print("\nПервые 5 строк данных:")
    print(loader.data.head())
# Out:
# Первые 5 строк данных:
#    user_id  session_duration  page_views  converted    country   device  \
# 0     1001             350.0           8          1        USA   mobile
# 1     1002             120.0           3          0         UK  desktop
# 2     1003             480.0          12          1     Canada   tablet
# 3     1004              65.0           2          0  Australia   mobile
# 4     1005             890.0          15          1        USA  desktop
#
#   age_group
# 0     18-25
# 1     26-35
# 2     36-45
# 3     18-25
# 4     46-55
